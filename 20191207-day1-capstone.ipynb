# %%
import os
print(os.getcwd())
# Out:
# C:\python\DAT264x Identifying Appliances from Energy Use Spectrogram

# %%
import matplotlib.pyplot as plt
sample = plt.imread('./train/1000_c.png')
sample.shape # RGBA

# %%
import matplotlib.pyplot as plt
sample = plt.imread('./data/train/1000_c.png')
sample.shape # RGBA
# Out:
# (128, 176, 4)

# %%
#Display
# %matplotlib inline
plt.figure(figsize=(2,2))
plt.imshow(sample)
plt.axis('off')
plt.show()
