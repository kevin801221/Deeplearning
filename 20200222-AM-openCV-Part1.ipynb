# %%
# opencv-python         4.1.1.26
import cv2
import matplotlib.pyplot as plt
andy2, andy2_cv2 = plt.imread('andy2.jpg'), cv2.imread('andy2.jpg')
andy2.shape, andy2_cv2.shape
# Out:
# ((250, 500, 3), (250, 500, 3))

# %%
plt.imshow(andy2_cv2)

# %%
andy2_cv2[:3] # 竟然跟matplotlib 讀取之後數據不同
# Out:
# array([[[ 92,  86,  81],
#         [ 92,  86,  81],
#         [ 92,  86,  81],
#         ...,
#         [225, 237, 241],
#         [226, 238, 242],
#         [227, 239, 243]],
#
#        [[ 91,  85,  80],
#         [ 91,  85,  80],
#         [ 91,  85,  80],
#         ...,
#         [225, 237, 241],
#         [226, 238, 242],
#         [227, 239, 243]],
#
#        [[ 91,  85,  80],
#         [ 91,  85,  80],
#         [ 91,  85,  80],
#         ...,
#         [226, 238, 242],
#         [226, 238, 242],
#         [227, 239, 243]]], dtype=uint8)

# %%
andy2[:3]
# Out:
# array([[[ 81,  86,  92],
#         [ 81,  86,  92],
#         [ 81,  86,  92],
#         ...,
#         [241, 237, 225],
#         [242, 238, 226],
#         [243, 239, 227]],
#
#        [[ 80,  85,  91],
#         [ 80,  85,  91],
#         [ 80,  85,  91],
#         ...,
#         [241, 237, 225],
#         [242, 238, 226],
#         [243, 239, 227]],
#
#        [[ 80,  85,  91],
#         [ 80,  85,  91],
#         [ 80,  85,  91],
#         ...,
#         [242, 238, 226],
#         [242, 238, 226],
#         [243, 239, 227]]], dtype=uint8)
