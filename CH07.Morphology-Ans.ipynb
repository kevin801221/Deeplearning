# %% [markdown]
# # 練習
# Handwritten letters
# A very interesting use of computer vision in real-life solutions is performing Optical Character Recognition (OCR) to distinguish printed or handwritten text characters inside digital images of physical documents.
#
# Let's try to improve the definition of this handwritten letter so that it's easier to classify.
#
#
# As we can see it's the letter R, already binary, with with some noise in it. It's already loaded as upper_r_image.
#
# Apply the morphological operation that will discard the pixels near the letter boundaries.
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline
# 準備作業
import matplotlib.pyplot as plt
def show_image(image, title='Image', cmap_type='gray', interpolation=None):
    plt.imshow(image, cmap=cmap_type)    
    plt.title(title)
    plt.axis('off')
    plt.show()
    
def plot_comparision(original, filtered, title_filtered):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(32,8), sharex=True, sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(title_filtered)
    ax2.axis('off')

from skimage import io
upper_r_image = io.imread('r5.png', as_gray='True')
# upper_r_image = plt.imread('r5.png')
upper_r_image.shape
# Import the module from scikit-image.
# Apply the morphological operation for eroding away the boundaries of regions of foreground pixels.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f18c996adb72> in <module>()
#      18     ax2.axis('off')
#      19
# ---> 20 from skimage import io
#      21 upper_r_image = io.imread('r5.png', as_gray='True')
#      22 # upper_r_image = plt.imread('r5.png')
#
# ~\Anaconda3\lib\site-packages\skimage\__init__.py in <module>()
#     156     except ImportError as e:
#     157         _raise_build_error(e)
# --> 158     from .util.dtype import *
#     159
#     160
#
# ~\Anaconda3\lib\site-packages\skimage\util\__init__.py in <module>()
#       5 from .apply_parallel import apply_parallel
#       6
# ----> 7 from .arraycrop import crop
#       8 from ._regular_grid import regular_grid, regular_seeds
#       9 from .unique import unique_rows
#
# ~\Anaconda3\lib\site-packages\skimage\util\arraycrop.py in <module>()
#       6
#       7 import numpy as np
# ----> 8 from numpy.lib.arraypad import _validate_lengths
#       9
#      10
#
# ImportError: cannot import name '_validate_lengths'

# %%
# Import the morphology module
from skimage import morphology
#from skimage import color
#upper_r_image = color.rgb2gray(upper_r_image)
# Obtain the eroded shape 
eroded_image_shape = morphology.binary_erosion(upper_r_image) 

# See results
show_image(upper_r_image, 'Original')
show_image(eroded_image_shape, 'Eroded image')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-f9f23b811d38> in <module>()
#       1 # Import the morphology module
# ----> 2 from skimage import morphology
#       3 #from skimage import color
#       4 #upper_r_image = color.rgb2gray(upper_r_image)
#       5 # Obtain the eroded shape
#
# ~\Anaconda3\lib\site-packages\skimage\morphology\__init__.py in <module>()
# ----> 1 from .binary import (binary_erosion, binary_dilation, binary_opening,
#       2                      binary_closing)
#       3 from .grey import (erosion, dilation, opening, closing, white_tophat,
#       4                    black_tophat)
#       5 from .selem import (square, rectangle, diamond, disk, cube, octahedron, ball,
#
# ~\Anaconda3\lib\site-packages\skimage\morphology\binary.py in <module>()
#       4 import numpy as np
#       5 from scipy import ndimage as ndi
# ----> 6 from .misc import default_selem
#       7
#       8
#
# ~\Anaconda3\lib\site-packages\skimage\morphology\misc.py in <module>()
#       2 import functools
#       3 from scipy import ndimage as ndi
# ----> 4 from .._shared.utils import warn
#       5 from .selem import _default_selem
#       6
#
# ~\Anaconda3\lib\site-packages\skimage\_shared\utils.py in <module>()
#       8 import six
#       9
# ---> 10 from ..util import img_as_float
#      11 from ._warnings import all_warnings, warn
#      12
#
# ~\Anaconda3\lib\site-packages\skimage\util\__init__.py in <module>()
#       5 from .apply_parallel import apply_parallel
#       6
# ----> 7 from .arraycrop import crop
#       8 from ._regular_grid import regular_grid, regular_seeds
#       9 from .unique import unique_rows
#
# ~\Anaconda3\lib\site-packages\skimage\util\arraycrop.py in <module>()
#       6
#       7 import numpy as np
# ----> 8 from numpy.lib.arraypad import _validate_lengths
#       9
#      10
#
# ImportError: cannot import name '_validate_lengths'

# %%
# 預期結果

original, erosion = plt.imread('original-r5.png'), \
                     plt.imread('erosion-r5.png')

plot_comparision(original, erosion, 'Erosion')

# %% [markdown]
# # 練習
# Improving thresholded image
# In this exercise, we'll try to reduce the noise of a thresholded image using the dilation morphological operation.
#
# World map
# Image already loaded as world_image.
# This operation, in a way, expands the objects in the image.
#
# ![image.png](attachment:image.png)

# %%
# 準備事項
world_image = plt.imread('world_image_binary.jpg')
world_image.shape

# Import the module.
# Obtain the binarized and dilated image, from the original image world_image.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-22d70dd9ba62> in <module>()
#       1 # 準備事項
# ----> 2 world_image = plt.imread('world_image_binary.jpg')
#       3 world_image.shape
#       4
#       5 # Import the module.
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(*args, **kwargs)
#    2379 @docstring.copy_dedent(_imread)
#    2380 def imread(*args, **kwargs):
# -> 2381     return _imread(*args, **kwargs)
#    2382
#    2383
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1354
#    1355     if ext not in handlers:
# -> 1356         im = pilread(fname)
#    1357         if im is None:
#    1358             raise ValueError('Only know how to handle extensions: %s; '
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in pilread(fname)
#    1332         except ImportError:
#    1333             return None
# -> 1334         with Image.open(fname) as image:
#    1335             return pil_to_array(image)
#    1336
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2546
#    2547     if filename:
# -> 2548         fp = builtins.open(filename, "rb")
#    2549         exclusive_fp = True
#    2550
#
# FileNotFoundError: [Errno 2] No such file or directory: 'world_image_binary.jpg'

# %%
# Import the module
from skimage import morphology

# Obtain the dilated image 
dilated_image = morphology.binary_dilation(world_image)

# See results
show_image(world_image, 'Original')
show_image(dilated_image, 'Dilated image')
