# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
I = plt.imread('rice.png'); 
plt.axis("off")
plt.imshow(I)

# %%
#Create a label matrix from the image.
BW = imbinarize(I); 
CC = bwconncomp(BW);
L = labelmatrix(CC);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8971ef62bb5c> in <module>
#       1 #Create a label matrix from the image.
# ----> 2 BW = imbinarize(I);
#       3 CC = bwconncomp(BW);
#       4 L = labelmatrix(CC);
#
# NameError: name 'imbinarize' is not defined
